# %%
import pandas as pd
import qgrid

# %%
file_enem_por_escola =  open(r'microdados_enem_por_escola\\dados\\MICRODADOS_ENEM_ESCOLA.csv')

# %%
campos_file = file_enem_por_escola.readline()

# %%
campos_file = campos_file.split(";")

# %%
pd.DataFrame(campos_file)
# Out:
#                             0
# 0                      NU_ANO
# 1                CO_UF_ESCOLA
# 2                SG_UF_ESCOLA
# 3         CO_MUNICIPIO_ESCOLA
# 4         NO_MUNICIPIO_ESCOLA
# 5        CO_ESCOLA_EDUCACENSO
# 6        NO_ESCOLA_EDUCACENSO
# 7   TP_DEPENDENCIA_ADM_ESCOLA
# 8       TP_LOCALIZACAO_ESCOLA
# 9               NU_MATRICULAS
# 10   NU_PARTICIPANTES_NEC_ESP
# 11           NU_PARTICIPANTES
# 12       NU_TAXA_PARTICIPACAO
# 13                NU_MEDIA_CN
# 14                NU_MEDIA_CH
# 15                NU_MEDIA_LP
# 16                NU_MEDIA_MT
# 17               NU_MEDIA_RED
# 18               NU_MEDIA_OBJ
# 19               NU_MEDIA_TOT
# 20                       INSE
# 21        PC_FORMACAO_DOCENTE
# 22        NU_TAXA_PERMANENCIA
# 23          NU_TAXA_APROVACAO
# 24         NU_TAXA_REPROVACAO
# 25           NU_TAXA_ABANDONO
# 26             PORTE_ESCOLA\n
